# %%
import tensorflow as tf
from tensorflow.keras import models 
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import fashion_mnist

# %% [markdown]
# 1..multi layer perceptron (코드를 그대로 사용했지만 분할 했을땐 오류 없이 잘되지만 분할하지 않고 CNN을 이용할때 오류가 계속 떠 분할 하였습니다.)

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()
y_train=to_categorical(y_train)
y_test=to_categorical(y_test)
X_train = X_train.reshape((60000, 28*28))
X_train = X_train/255
X_test = X_test.reshape((10000, 28*28))
X_test = X_test/255
net = models.Sequential()
net.add(layers.Dense(512, activation='relu', input_shape=(28*28,))) 
net.add(layers.Dense(512, activation='relu')) 
net.add(layers.Dropout(0.4))
net.add(layers.Dense(512, activation='relu')) 
net.add(layers.Dropout(0.4))
net.add(layers.Dense(10, activation='softmax')) 
net.compile(optimizer='nadam',loss='categorical_crossentropy',metrics=['acc'])

# %%
X_val = X_train[:10000]
partial_X_train = X_train[10000:]
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
val= net.fit(partial_X_train,partial_y_train,epochs=10, batch_size=64, validation_data=(X_val, y_val))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/10
# 50000/50000 [==============================] - 33s 664us/sample - loss: 0.5381 - acc: 0.8054 - val_loss: 0.4957 - val_acc: 0.8083
# Epoch 2/10
# 50000/50000 [==============================] - 32s 642us/sample - loss: 0.3829 - acc: 0.8613 - val_loss: 0.3729 - val_acc: 0.8668
# Epoch 3/10
# 50000/50000 [==============================] - 31s 616us/sample - loss: 0.3452 - acc: 0.8748 - val_loss: 0.3290 - val_acc: 0.8843
# Epoch 4/10
# 50000/50000 [==============================] - 34s 674us/sample - loss: 0.3181 - acc: 0.8826 - val_loss: 0.3476 - val_acc: 0.8747
# Epoch 5/10
# 50000/50000 [==============================] - 31s 629us/sample - loss: 0.3045 - acc: 0.8901 - val_loss: 0.3243 - val_acc: 0.8796
# Epoch 6/10
# 50000/50000 [==============================] - 31s 619us/sample - loss: 0.2878 - acc: 0.8944 - val_loss: 0.3224 - val_acc: 0.8856
# Epoch 7/10
# 50000/50000 [==============================] - 30s 608us/sample - loss: 0.2747 - acc: 0.8990 - val_loss: 0.3043 - val_acc: 0.8892
# Epoch 8/10
# 50000/50000 [==============================] - 31s 626us/sample - loss: 0.2647 - acc: 0.9015 - val_loss: 0.3120 - val_acc: 0.8888
# Epoch 9/10
# 50000/50000 [==============================] - 31s 620us/sample - loss: 0.2575 - acc: 0.9057 - val_loss: 0.3219 - val_acc: 0.8861
# Epoch 10/10
# 50000/50000 [==============================] - 32s 633us/sample - loss: 0.2481 - acc: 0.9080 - val_loss: 0.3008 - val_acc: 0.8913

# %%
test_loss, test_acc = net.evaluate(X_test,y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
