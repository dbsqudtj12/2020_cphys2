# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import models 
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence

# %% [markdown]
# 1. RNN

# %%
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=10000)

# %%
max_words=10000 
maxlen = 100
X_train = sequence.pad_sequences(X_train, maxlen=maxlen)
X_test = sequence.pad_sequences(X_test, maxlen=maxlen)

# %%
rnn = models.Sequential()
rnn.add(layers.Embedding(max_words, 16)) 
rnn.add(layers.SimpleRNN(16,return_sequences='True')) 
rnn.add(layers.Dropout(0.5))
rnn.add(layers.SimpleRNN(16))
rnn.add(layers.Dropout(0.5))
rnn.add(layers.Dense(1, activation='sigmoid'))
rnn.compile(optimizer='nadam',loss='binary_crossentropy',metrics=['acc'])

# %%
history = rnn.fit(X_train,y_train,epochs=5, batch_size=64,validation_split=0.2)
# Out:
# Train on 20000 samples, validate on 5000 samples
# Epoch 1/5
# 20000/20000 [==============================] - 28s 1ms/sample - loss: 0.6890 - acc: 0.5614 - val_loss: 0.6994 - val_acc: 0.5300
# Epoch 2/5
# 20000/20000 [==============================] - 24s 1ms/sample - loss: 0.5328 - acc: 0.7416 - val_loss: 0.4297 - val_acc: 0.8090
# Epoch 3/5
# 20000/20000 [==============================] - 28s 1ms/sample - loss: 0.3784 - acc: 0.8516 - val_loss: 0.4416 - val_acc: 0.8160
# Epoch 4/5
# 20000/20000 [==============================] - 26s 1ms/sample - loss: 0.3084 - acc: 0.8868 - val_loss: 0.4009 - val_acc: 0.8324
# Epoch 5/5
# 20000/20000 [==============================] - 27s 1ms/sample - loss: 0.2486 - acc: 0.9137 - val_loss: 0.4626 - val_acc: 0.8276

# %%
test_loss, test_acc = rnn.evaluate(X_test,y_test)
# Out:
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %% [markdown]
# hw10_2는 simpleRNN과적합이 심하고 정확도도 잘 안나와 RNN의 단점을 보완해주는 LSTM으로
# 해본것 입니다.
